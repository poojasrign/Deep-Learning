# %% [markdown]
# <a href="https://colab.research.google.com/github/poojasrign/Deep-Learning/blob/main/Ex_5_Sentiment_Analysis_using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 10000   # Top 10k words
maxlen = 200         # Max length of review
embedding_dim = 128

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=maxlen))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=64, epochs=3, validation_data=(X_test, y_test))
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {acc * 100:.2f}%")
# Out:
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 315s 794ms/step - accuracy: 0.7029 - loss: 0.5590 - val_accuracy: 0.7983 - val_loss: 0.4491
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 308s 788ms/step - accuracy: 0.8465 - loss: 0.3664 - val_accuracy: 0.8438 - val_loss: 0.3872
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 306s 783ms/step - accuracy: 0.8663 - loss: 0.3293 - val_accuracy: 0.8247 - val_loss: 0.4196
# Test Accuracy: 82.47%
